# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("winequality.csv",sep=";")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# # find the missing values

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # split input and output

# %%
feature=df.iloc[:,:-1]
target=df.iloc[:,-1]

# %%
feature
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
target
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %% [markdown]
# # outliers

# %%
q1=np.quantile(df["residual sugar"],0.25)
q3=np.quantile(df["residual sugar"],0.75)
iqr=q3-q1
uw=q3+1.5*iqr
lw=q1-1.5*iqr
print(uw)
# Out:
# 22.200000000000003

# %%
q1=np.quantile(df["chlorides"],0.25)
q3=np.quantile(df["chlorides"],0.75)
iqr=q3-q1
uw=q3+1.5*iqr
lw=q1-1.5*iqr
print(uw)
# Out:
# 0.07100000000000001

# %%
q1=np.quantile(df["free sulfur dioxide"],0.25)
q3=np.quantile(df["free sulfur dioxide"],0.75)
iqr=q3-q1
uw=q3+1.5*iqr
lw=q1-1.5*iqr
print(uw)
# Out:
# 80.5

# %%
q1=np.quantile(df["citric acid"],0.25)
q3=np.quantile(df["citric acid"],0.75)
iqr=q3-q1
uw=q3+1.5*iqr
lw=q1-1.5*iqr
print(uw)
# Out:
# 0.5700000000000001

# %%
q1=np.quantile(df["volatile acidity"],0.25)
q3=np.quantile(df["volatile acidity"],0.75)
iqr=q3-q1
uw=q3+1.5*iqr
lw=q1-1.5*iqr
print(uw)
# Out:
# 0.48500000000000004

# %%
q1=np.quantile(df["fixed acidity"],0.25)
q3=np.quantile(df["fixed acidity"],0.75)
iqr=q3-q1
uw=q3+1.5*iqr
lw=q1-1.5*iqr
print(uw)
# Out:
# 8.8

# %%
sns.boxplot(data=feature,x=target)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(data=df,x=target,y="fixed acidity")
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(data=df,x=target,y="volatile acidity")
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(data=df,x=target,y="citric acid")
plt.show()

# %%
feature.drop(["fixed acidity"],axis=1)
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 0                 0.27         0.36            20.7      0.045
# 1                 0.30         0.34             1.6      0.049
# 2                 0.28         0.40             6.9      0.050
# 3                 0.23         0.32             8.5      0.058
# 4                 0.23         0.32             8.5      0.058
# ...                ...          ...             ...        ...
# 4893              0.21         0.29             1.6      0.039
# 4894              0.32         0.36             8.0      0.047
# 4895              0.24         0.19             1.2      0.041
# 4896              0.29         0.30             1.1      0.022
# 4897              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# ...

# %% [markdown]
# # skew handling

# %%
from scipy.stats import skew

# %%
for col in feature:
    print(col)
    print(skew(feature[col]))
    plt.figure()
    sns.distplot(feature[col])
    plt.show()
# Out:
# fixed acidity
# 0.6475530855160632
# volatile acidity
# 1.576496515957486
# citric acid
# 1.2815277799152376
# residual sugar
# 1.0767638711454448
# chlorides
# 5.0217921696710315
# free sulfur dioxide
# 1.4063140718346216
# total sulfur dioxide
# 0.39059017758152365
# density
# 0.9774735389049212
# pH
# 0.457642339253789
# sulphates
# 0.9768943947733427
# alcohol
# 0.48719273327634327

# %%
pd.concat([feature,target],axis=1).corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
pd.concat([feature,target],axis=1).corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_a0cfa_row0_col0, #T_a0cfa_row1_col1, #T_a0cfa_row2_col2, #T_a0cfa_row3_col3, #T_a0cfa_row4_col4, #T_a0cfa_row5_col5, #T_a0cfa_row6_col6, #T_a0cfa_row7_col7, #T_a0cfa_row8_col8, #T_a0cfa_row9_col9, #T_a0cfa_row10_col10, #T_a0cfa_row11_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a0cfa_row0_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a0cfa_row0_col2 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_a0cfa_row0_col3, #T_a0cfa_row0_col6, #T_a0cfa_row1_col6, #T_a0cfa_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_a0cfa_row0_col4, #T_a0cfa_row1_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_a0cfa_row0_col5, #T_a0cfa_row3_col8, #T_a0cfa_row3_col11 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_a0cfa_row0_col7, #T_a0cfa_row3_col6, #T_a0cfa_row6_col3 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# ...

# %%
pd.concat([feature,target],axis=1).corr()["quality"]
# Out:
# fixed acidity          -0.113663
# volatile acidity       -0.194723
# citric acid            -0.009209
# residual sugar         -0.097577
# chlorides              -0.209934
# free sulfur dioxide     0.008158
# total sulfur dioxide   -0.174737
# density                -0.307123
# pH                      0.099427
# sulphates               0.053678
# alcohol                 0.435575
# quality                 1.000000
# Name: quality, dtype: float64

# %%
feature["citric acid"].value_counts()
# Out:
# 0.30    307
# 0.28    282
# 0.32    257
# 0.34    225
# 0.29    223
#        ...
# 1.66      1
# 1.23      1
# 0.86      1
# 0.11      1
# 0.99      1
# Name: citric acid, Length: 87, dtype: int64

# %% [markdown]
# # OrdinalEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder
on=OrdinalEncoder()
on.fit_transform(feature)
# Out:
# array([[31., 36., 36., ..., 23., 22.,  5.],
#        [23., 42., 34., ..., 53., 26., 12.],
#        [43., 38., 40., ..., 49., 21., 24.],
#        ...,
#        [26., 30., 19., ..., 22., 23., 11.],
#        [14., 40., 30., ..., 57., 15., 84.],
#        [19., 24., 38., ..., 49.,  9., 65.]])

# %%
catcol=feature.select_dtypes("object").columns

# %%
catcol
# Out:
# Index([], dtype='object')

# %%
feature[catcol]=on.fit_transform(feature[catcol])
feature
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # split training and testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(feature,target,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([5.22901188, 5.54653092, 6.11293343, ..., 5.95521601, 5.44988236,
#        6.25912797])

# %% [markdown]
# # Evaluation metrics

# %%
lr.coef_
# Out:
# array([ 5.05720124e-02, -1.99701100e+00,  2.86986515e-03,  7.87685381e-02,
#        -5.26695620e-01,  2.88140351e-03,  4.27771478e-05, -1.34394915e+02,
#         6.26499100e-01,  5.76517695e-01,  2.20279529e-01])

# %%
lr.intercept_
# Out:
# 134.49433807676212

# %%
plt.scatter(ytest,ypred)
plt.show()
